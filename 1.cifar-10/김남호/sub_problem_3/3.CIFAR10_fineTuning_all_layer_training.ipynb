# %% [markdown]
# <a href="https://colab.research.google.com/github/skaghzz/research/blob/master/1.cifar-10/%EA%B9%80%EB%82%A8%ED%98%B8/sub_problem_3/3.CIFAR10_fineTuning_all_layer_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://jjeongil.tistory.com/855

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.datasets import cifar10

from sklearn.model_selection import train_test_split

import numpy as np
import matplotlib.pyplot as plt
import os

import cv2

tf.__version__
# Out:
# '2.3.0'

# %%
# hyperparameter
batch_size = 100
epochs = 50
learning_rate = 0.0001

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

x_train_ori = x_train.copy()
y_train_ori = y_train.copy()

#x_train = tf.image.resize(x_train, [72, 72])
#x_train_ori = tf.image.resize(x_train_ori, [72, 72])

x_aug_train, x_aug_valid, y_aug_train, y_aug_valid = train_test_split(x_train, y_train, test_size=0.2, shuffle=True)
x_ori_train, x_ori_valid, y_ori_train, y_ori_valid = train_test_split(x_train_ori, y_train_ori, test_size=0.2, shuffle=True)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
augmented_train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=30,  ## 무작위 회전 각도 범위
    width_shift_range=0.2, ## 가로로 이동 비율
    height_shift_range=0.2,  ## 세로로 이동 비율
    shear_range=0.2,  # 층밀리기의 강도
    zoom_range=0.2, ## 확대 와 축소 범위 [1-0.1 ~ 1+0.1 ]
    horizontal_flip=True, ## 수평기준 플립
    #vertical_flip=True,
    #validation_split=0.2, # 검증의 용도로 남겨둘 남겨둘 이미지의 비율
)

augmented_train_datagen.fit(x_aug_train, augment=True)

x_train = tf.concat([x_aug_train, x_ori_train],0)
y_train = tf.concat([y_aug_train, y_ori_train],0)
x_valid = tf.concat([x_aug_valid, x_ori_valid],0)
y_valid = tf.concat([y_aug_valid, y_ori_valid],0)
train_gen_flow = augmented_train_datagen.flow(x_train, y_train, batch_size=batch_size)
valid_gen_flow = augmented_train_datagen.flow(x_valid, y_valid, batch_size=batch_size)
print(len(train_gen_flow))
print(len(valid_gen_flow))
# Out:
# 800
# 200

# %%
checkpoint_dir = 'cifar10_classification/exp1'
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=1)
cos_decay = tf.keras.experimental.CosineDecay(learning_rate, epochs)
lr_callback = tf.keras.callbacks.LearningRateScheduler(cos_decay, verbose=1)
early_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# %%
# 사전 훈련된 모델 Xception에서 기본 모델을 생성합니다.
base_model = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', pooling='avg', input_shape=(32,32,3))
base_model.trainable = True
base_model.summary()

'''
set_trainable = False
for layer in base_model.layers:
  if layer.name == 'conv5_block2_add':
    set_trainable =  True
  if set_trainable:
    layer.trainable = True
  else:
    layer.trainable = False
# 모델
'''
input_layer = tf.keras.layers.Input(shape=(32,32,3))
x = base_model(input_layer)
#x = tf.keras.layers.GlobalAveragePooling2D()(x)
#x = tf.keras.layers.Flatten()(x)
#x = tf.keras.layers.Dense(1024, activation='relu')(x)
#x = tf.keras.layers.Dropout(0.5)(x)
out_layer = tf.keras.layers.Dense(10, activation='softmax')(x)

model = tf.keras.Model(inputs=[input_layer], outputs=[out_layer])
model.summary()
model.compile(loss = tf.keras.losses.sparse_categorical_crossentropy,
              optimizer = tf.keras.optimizers.Adam(),
              metrics=[tf.keras.metrics.sparse_categorical_accuracy])
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 16, 16, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 18, 18, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 8, 8, 64)     0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 8, 8, 64)     4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 8, 8, 64)     0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 8, 8, 64)     0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 8, 8, 256)    16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 8, 8, 256)    0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 8, 8, 256)    0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 8, 8, 64)     16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 8, 8, 64)     0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 8, 8, 64)     0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 8, 8, 256)    0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 8, 8, 256)    0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 8, 8, 64)     16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 8, 8, 64)     0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 8, 8, 64)     0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 8, 8, 256)    0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 8, 8, 256)    0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 4, 4, 128)    32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 4, 4, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 4, 4, 128)    0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 4, 4, 512)    131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 4, 4, 512)    0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 4, 4, 512)    0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 4, 4, 128)    65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 4, 4, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 4, 4, 128)    0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 4, 4, 512)    0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 4, 4, 512)    0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 4, 4, 128)    65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 4, 4, 128)    0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 4, 4, 128)    0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 4, 4, 512)    0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 4, 4, 512)    0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 4, 4, 128)    65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 4, 4, 128)    0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 4, 4, 128)    0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 4, 4, 512)    0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 4, 4, 512)    0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 2, 2, 256)    131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 2, 2, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 2, 2, 256)    0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 2, 2, 1024)   525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 2, 2, 1024)   0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 2, 2, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 2, 2, 256)    0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 2, 2, 1024)   0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 2, 2, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 2, 2, 256)    0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 2, 2, 1024)   0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 2, 2, 1024)   0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 2, 2, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 2, 2, 256)    0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 2, 2, 1024)   0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 2, 2, 1024)   0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 2, 2, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 2, 2, 256)    0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 2, 2, 1024)   0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 2, 2, 1024)   0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 2, 2, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 2, 2, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 2, 2, 1024)   0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 2, 2, 1024)   0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 1, 1, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 1, 1, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 1, 1, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 1, 1, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 1, 1, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 1, 1, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 1, 1, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 1, 1, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 1, 1, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 1, 1, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 1, 1, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 1, 1, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 1, 1, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 1, 1, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 1, 1, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 1, 1, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 1, 1, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 1, 1, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 1, 1, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 1, 1, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 1, 1, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 1, 1, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           conv5_block3_out[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# dense (Dense)                (None, 10)                20490
# =================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
history = model.fit(
    train_gen_flow,
    steps_per_epoch= len(train_gen_flow),
    epochs=epochs,
    validation_data=valid_gen_flow,
    validation_steps = len(valid_gen_flow),
    callbacks=[cp_callback, lr_callback, early_callback]
)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(1e-04, shape=(), dtype=float32).
# Epoch 1/50
# 800/800 [==============================] - ETA: 0s - loss: 1.4729 - sparse_categorical_accuracy: 0.5120
# Epoch 00001: val_loss improved from inf to 2.67502, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 66s 82ms/step - loss: 1.4729 - sparse_categorical_accuracy: 0.5120 - val_loss: 2.6750 - val_sparse_categorical_accuracy: 0.2261
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(9.9901335e-05, shape=(), dtype=float32).
# Epoch 2/50
# 800/800 [==============================] - ETA: 0s - loss: 0.9373 - sparse_categorical_accuracy: 0.6751
# Epoch 00002: val_loss improved from 2.67502 to 0.93618, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.9373 - sparse_categorical_accuracy: 0.6751 - val_loss: 0.9362 - val_sparse_categorical_accuracy: 0.6976
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(9.9605735e-05, shape=(), dtype=float32).
# Epoch 3/50
# 800/800 [==============================] - ETA: 0s - loss: 0.7937 - sparse_categorical_accuracy: 0.7254
# Epoch 00003: val_loss improved from 0.93618 to 0.83017, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.7937 - sparse_categorical_accuracy: 0.7254 - val_loss: 0.8302 - val_sparse_categorical_accuracy: 0.7247
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(9.911435e-05, shape=(), dtype=float32).
# Epoch 4/50
# 800/800 [==============================] - ETA: 0s - loss: 0.7117 - sparse_categorical_accuracy: 0.7546
# Epoch 00004: val_loss did not improve from 0.83017
# 800/800 [==============================] - 65s 81ms/step - loss: 0.7117 - sparse_categorical_accuracy: 0.7546 - val_loss: 0.8345 - val_sparse_categorical_accuracy: 0.7191
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(9.8429155e-05, shape=(), dtype=float32).
# Epoch 5/50
# 800/800 [==============================] - ETA: 0s - loss: 0.6646 - sparse_categorical_accuracy: 0.7703
# Epoch 00005: val_loss improved from 0.83017 to 0.68865, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.6646 - sparse_categorical_accuracy: 0.7703 - val_loss: 0.6886 - val_sparse_categorical_accuracy: 0.7697
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(9.7552824e-05, shape=(), dtype=float32).
# Epoch 6/50
# 800/800 [==============================] - ETA: 0s - loss: 0.6105 - sparse_categorical_accuracy: 0.7872
# Epoch 00006: val_loss improved from 0.68865 to 0.62419, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.6105 - sparse_categorical_accuracy: 0.7872 - val_loss: 0.6242 - val_sparse_categorical_accuracy: 0.7807
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(9.648882e-05, shape=(), dtype=float32).
# Epoch 7/50
# 800/800 [==============================] - ETA: 0s - loss: 0.5753 - sparse_categorical_accuracy: 0.8001
# Epoch 00007: val_loss improved from 0.62419 to 0.61395, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.5753 - sparse_categorical_accuracy: 0.8001 - val_loss: 0.6140 - val_sparse_categorical_accuracy: 0.7902
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(9.5241354e-05, shape=(), dtype=float32).
# Epoch 8/50
# 800/800 [==============================] - ETA: 0s - loss: 0.5512 - sparse_categorical_accuracy: 0.8094
# Epoch 00008: val_loss improved from 0.61395 to 0.57812, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.5512 - sparse_categorical_accuracy: 0.8094 - val_loss: 0.5781 - val_sparse_categorical_accuracy: 0.8013
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(9.381533e-05, shape=(), dtype=float32).
# Epoch 9/50
# 800/800 [==============================] - ETA: 0s - loss: 0.5388 - sparse_categorical_accuracy: 0.8138
# Epoch 00009: val_loss improved from 0.57812 to 0.56376, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.5388 - sparse_categorical_accuracy: 0.8138 - val_loss: 0.5638 - val_sparse_categorical_accuracy: 0.8050
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(9.2216396e-05, shape=(), dtype=float32).
# Epoch 10/50
# 800/800 [==============================] - ETA: 0s - loss: 0.4962 - sparse_categorical_accuracy: 0.8255
# Epoch 00010: val_loss improved from 0.56376 to 0.53050, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.4962 - sparse_categorical_accuracy: 0.8255 - val_loss: 0.5305 - val_sparse_categorical_accuracy: 0.8148
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(9.045084e-05, shape=(), dtype=float32).
# Epoch 11/50
# 800/800 [==============================] - ETA: 0s - loss: 0.4554 - sparse_categorical_accuracy: 0.8423
# Epoch 00011: val_loss improved from 0.53050 to 0.51361, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.4554 - sparse_categorical_accuracy: 0.8423 - val_loss: 0.5136 - val_sparse_categorical_accuracy: 0.8221
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(8.852566e-05, shape=(), dtype=float32).
# Epoch 12/50
# 800/800 [==============================] - ETA: 0s - loss: 0.4306 - sparse_categorical_accuracy: 0.8489
# Epoch 00012: val_loss improved from 0.51361 to 0.48865, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.4306 - sparse_categorical_accuracy: 0.8489 - val_loss: 0.4886 - val_sparse_categorical_accuracy: 0.8311
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(8.644843e-05, shape=(), dtype=float32).
# Epoch 13/50
# 800/800 [==============================] - ETA: 0s - loss: 0.4362 - sparse_categorical_accuracy: 0.8473
# Epoch 00013: val_loss improved from 0.48865 to 0.46651, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.4362 - sparse_categorical_accuracy: 0.8473 - val_loss: 0.4665 - val_sparse_categorical_accuracy: 0.8358
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(8.422736e-05, shape=(), dtype=float32).
# Epoch 14/50
# 800/800 [==============================] - ETA: 0s - loss: 0.3919 - sparse_categorical_accuracy: 0.8631
# Epoch 00014: val_loss improved from 0.46651 to 0.45865, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.3919 - sparse_categorical_accuracy: 0.8631 - val_loss: 0.4586 - val_sparse_categorical_accuracy: 0.8407
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(8.18712e-05, shape=(), dtype=float32).
# Epoch 15/50
# 800/800 [==============================] - ETA: 0s - loss: 0.3779 - sparse_categorical_accuracy: 0.8676
# Epoch 00015: val_loss did not improve from 0.45865
# 800/800 [==============================] - 63s 79ms/step - loss: 0.3779 - sparse_categorical_accuracy: 0.8676 - val_loss: 0.4663 - val_sparse_categorical_accuracy: 0.8377
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(7.938926e-05, shape=(), dtype=float32).
# Epoch 16/50
# 800/800 [==============================] - ETA: 0s - loss: 0.3567 - sparse_categorical_accuracy: 0.8759
# Epoch 00016: val_loss improved from 0.45865 to 0.42582, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.3567 - sparse_categorical_accuracy: 0.8759 - val_loss: 0.4258 - val_sparse_categorical_accuracy: 0.8530
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(7.679133e-05, shape=(), dtype=float32).
# Epoch 17/50
# 800/800 [==============================] - ETA: 0s - loss: 0.3289 - sparse_categorical_accuracy: 0.8849
# Epoch 00017: val_loss improved from 0.42582 to 0.40161, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.3289 - sparse_categorical_accuracy: 0.8849 - val_loss: 0.4016 - val_sparse_categorical_accuracy: 0.8629
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(7.408768e-05, shape=(), dtype=float32).
# Epoch 18/50
# 800/800 [==============================] - ETA: 0s - loss: 0.3089 - sparse_categorical_accuracy: 0.8909
# Epoch 00018: val_loss did not improve from 0.40161
# 800/800 [==============================] - 64s 80ms/step - loss: 0.3089 - sparse_categorical_accuracy: 0.8909 - val_loss: 0.4029 - val_sparse_categorical_accuracy: 0.8597
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(7.128896e-05, shape=(), dtype=float32).
# Epoch 19/50
# 800/800 [==============================] - ETA: 0s - loss: 0.2924 - sparse_categorical_accuracy: 0.8988
# Epoch 00019: val_loss improved from 0.40161 to 0.39123, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.2924 - sparse_categorical_accuracy: 0.8988 - val_loss: 0.3912 - val_sparse_categorical_accuracy: 0.8659
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(6.8406225e-05, shape=(), dtype=float32).
# Epoch 20/50
# 800/800 [==============================] - ETA: 0s - loss: 0.2815 - sparse_categorical_accuracy: 0.9018
# Epoch 00020: val_loss improved from 0.39123 to 0.37230, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.2815 - sparse_categorical_accuracy: 0.9018 - val_loss: 0.3723 - val_sparse_categorical_accuracy: 0.8751
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(6.545085e-05, shape=(), dtype=float32).
# Epoch 21/50
# 800/800 [==============================] - ETA: 0s - loss: 0.2653 - sparse_categorical_accuracy: 0.9087
# Epoch 00021: val_loss improved from 0.37230 to 0.35344, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.2653 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.3534 - val_sparse_categorical_accuracy: 0.8803
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(6.24345e-05, shape=(), dtype=float32).
# Epoch 22/50
# 800/800 [==============================] - ETA: 0s - loss: 0.2496 - sparse_categorical_accuracy: 0.9134
# Epoch 00022: val_loss improved from 0.35344 to 0.35160, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.2496 - sparse_categorical_accuracy: 0.9134 - val_loss: 0.3516 - val_sparse_categorical_accuracy: 0.8788
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(5.936906e-05, shape=(), dtype=float32).
# Epoch 23/50
# 800/800 [==============================] - ETA: 0s - loss: 0.2311 - sparse_categorical_accuracy: 0.9196
# Epoch 00023: val_loss improved from 0.35160 to 0.33422, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.2311 - sparse_categorical_accuracy: 0.9196 - val_loss: 0.3342 - val_sparse_categorical_accuracy: 0.8879
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(5.6266654e-05, shape=(), dtype=float32).
# Epoch 24/50
# 800/800 [==============================] - ETA: 0s - loss: 0.2209 - sparse_categorical_accuracy: 0.9239
# Epoch 00024: val_loss did not improve from 0.33422
# 800/800 [==============================] - 63s 79ms/step - loss: 0.2209 - sparse_categorical_accuracy: 0.9239 - val_loss: 0.3514 - val_sparse_categorical_accuracy: 0.8842
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(5.3139524e-05, shape=(), dtype=float32).
# Epoch 25/50
# 800/800 [==============================] - ETA: 0s - loss: 0.2079 - sparse_categorical_accuracy: 0.9274
# Epoch 00025: val_loss improved from 0.33422 to 0.31661, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.2079 - sparse_categorical_accuracy: 0.9274 - val_loss: 0.3166 - val_sparse_categorical_accuracy: 0.8943
#
# Epoch 00026: LearningRateScheduler reducing learning rate to tf.Tensor(4.9999995e-05, shape=(), dtype=float32).
# Epoch 26/50
# 800/800 [==============================] - ETA: 0s - loss: 0.2002 - sparse_categorical_accuracy: 0.9313
# Epoch 00026: val_loss improved from 0.31661 to 0.30729, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.2002 - sparse_categorical_accuracy: 0.9313 - val_loss: 0.3073 - val_sparse_categorical_accuracy: 0.8976
#
# Epoch 00027: LearningRateScheduler reducing learning rate to tf.Tensor(4.6860478e-05, shape=(), dtype=float32).
# Epoch 27/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1879 - sparse_categorical_accuracy: 0.9348
# Epoch 00027: val_loss improved from 0.30729 to 0.30287, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 82ms/step - loss: 0.1879 - sparse_categorical_accuracy: 0.9348 - val_loss: 0.3029 - val_sparse_categorical_accuracy: 0.9003
#
# Epoch 00028: LearningRateScheduler reducing learning rate to tf.Tensor(4.3733333e-05, shape=(), dtype=float32).
# Epoch 28/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1751 - sparse_categorical_accuracy: 0.9397
# Epoch 00028: val_loss improved from 0.30287 to 0.27491, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 66s 82ms/step - loss: 0.1751 - sparse_categorical_accuracy: 0.9397 - val_loss: 0.2749 - val_sparse_categorical_accuracy: 0.9076
#
# Epoch 00029: LearningRateScheduler reducing learning rate to tf.Tensor(4.0630934e-05, shape=(), dtype=float32).
# Epoch 29/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1624 - sparse_categorical_accuracy: 0.9438
# Epoch 00029: val_loss improved from 0.27491 to 0.27275, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 81ms/step - loss: 0.1624 - sparse_categorical_accuracy: 0.9438 - val_loss: 0.2728 - val_sparse_categorical_accuracy: 0.9118
#
# Epoch 00030: LearningRateScheduler reducing learning rate to tf.Tensor(3.7565504e-05, shape=(), dtype=float32).
# Epoch 30/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1548 - sparse_categorical_accuracy: 0.9465
# Epoch 00030: val_loss improved from 0.27275 to 0.26979, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 81ms/step - loss: 0.1548 - sparse_categorical_accuracy: 0.9465 - val_loss: 0.2698 - val_sparse_categorical_accuracy: 0.9131
#
# Epoch 00031: LearningRateScheduler reducing learning rate to tf.Tensor(3.454914e-05, shape=(), dtype=float32).
# Epoch 31/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1465 - sparse_categorical_accuracy: 0.9496
# Epoch 00031: val_loss improved from 0.26979 to 0.25507, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.1465 - sparse_categorical_accuracy: 0.9496 - val_loss: 0.2551 - val_sparse_categorical_accuracy: 0.9157
#
# Epoch 00032: LearningRateScheduler reducing learning rate to tf.Tensor(3.159377e-05, shape=(), dtype=float32).
# Epoch 32/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1383 - sparse_categorical_accuracy: 0.9527
# Epoch 00032: val_loss did not improve from 0.25507
# 800/800 [==============================] - 63s 79ms/step - loss: 0.1383 - sparse_categorical_accuracy: 0.9527 - val_loss: 0.4417 - val_sparse_categorical_accuracy: 0.9109
#
# Epoch 00033: LearningRateScheduler reducing learning rate to tf.Tensor(2.8711032e-05, shape=(), dtype=float32).
# Epoch 33/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1303 - sparse_categorical_accuracy: 0.9556
# Epoch 00033: val_loss improved from 0.25507 to 0.23864, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.1303 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.2386 - val_sparse_categorical_accuracy: 0.9230
#
# Epoch 00034: LearningRateScheduler reducing learning rate to tf.Tensor(2.5912308e-05, shape=(), dtype=float32).
# Epoch 34/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1242 - sparse_categorical_accuracy: 0.9580
# Epoch 00034: val_loss improved from 0.23864 to 0.23703, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.1242 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.2370 - val_sparse_categorical_accuracy: 0.9258
#
# Epoch 00035: LearningRateScheduler reducing learning rate to tf.Tensor(2.3208653e-05, shape=(), dtype=float32).
# Epoch 35/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1162 - sparse_categorical_accuracy: 0.9602
# Epoch 00035: val_loss improved from 0.23703 to 0.23146, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.1162 - sparse_categorical_accuracy: 0.9602 - val_loss: 0.2315 - val_sparse_categorical_accuracy: 0.9273
#
# Epoch 00036: LearningRateScheduler reducing learning rate to tf.Tensor(2.0610738e-05, shape=(), dtype=float32).
# Epoch 36/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1125 - sparse_categorical_accuracy: 0.9611
# Epoch 00036: val_loss improved from 0.23146 to 0.22792, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.1125 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.2279 - val_sparse_categorical_accuracy: 0.9294
#
# Epoch 00037: LearningRateScheduler reducing learning rate to tf.Tensor(1.812879e-05, shape=(), dtype=float32).
# Epoch 37/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1054 - sparse_categorical_accuracy: 0.9640
# Epoch 00037: val_loss improved from 0.22792 to 0.20933, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.1054 - sparse_categorical_accuracy: 0.9640 - val_loss: 0.2093 - val_sparse_categorical_accuracy: 0.9344
#
# Epoch 00038: LearningRateScheduler reducing learning rate to tf.Tensor(1.5772643e-05, shape=(), dtype=float32).
# Epoch 38/50
# 800/800 [==============================] - ETA: 0s - loss: 0.1015 - sparse_categorical_accuracy: 0.9660
# Epoch 00038: val_loss did not improve from 0.20933
# 800/800 [==============================] - 63s 79ms/step - loss: 0.1015 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.2110 - val_sparse_categorical_accuracy: 0.9329
#
# Epoch 00039: LearningRateScheduler reducing learning rate to tf.Tensor(1.3551568e-05, shape=(), dtype=float32).
# Epoch 39/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0971 - sparse_categorical_accuracy: 0.9674
# Epoch 00039: val_loss improved from 0.20933 to 0.20756, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0971 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.2076 - val_sparse_categorical_accuracy: 0.9351
#
# Epoch 00040: LearningRateScheduler reducing learning rate to tf.Tensor(1.1474338e-05, shape=(), dtype=float32).
# Epoch 40/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0930 - sparse_categorical_accuracy: 0.9686
# Epoch 00040: val_loss did not improve from 0.20756
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0930 - sparse_categorical_accuracy: 0.9686 - val_loss: 0.2108 - val_sparse_categorical_accuracy: 0.9359
#
# Epoch 00041: LearningRateScheduler reducing learning rate to tf.Tensor(9.54915e-06, shape=(), dtype=float32).
# Epoch 41/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0873 - sparse_categorical_accuracy: 0.9700
# Epoch 00041: val_loss improved from 0.20756 to 0.20256, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0873 - sparse_categorical_accuracy: 0.9700 - val_loss: 0.2026 - val_sparse_categorical_accuracy: 0.9370
#
# Epoch 00042: LearningRateScheduler reducing learning rate to tf.Tensor(7.7836e-06, shape=(), dtype=float32).
# Epoch 42/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0873 - sparse_categorical_accuracy: 0.9716
# Epoch 00042: val_loss improved from 0.20256 to 0.19905, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 81ms/step - loss: 0.0873 - sparse_categorical_accuracy: 0.9716 - val_loss: 0.1990 - val_sparse_categorical_accuracy: 0.9392
#
# Epoch 00043: LearningRateScheduler reducing learning rate to tf.Tensor(6.1846704e-06, shape=(), dtype=float32).
# Epoch 43/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0840 - sparse_categorical_accuracy: 0.9721
# Epoch 00043: val_loss did not improve from 0.19905
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0840 - sparse_categorical_accuracy: 0.9721 - val_loss: 0.1998 - val_sparse_categorical_accuracy: 0.9405
#
# Epoch 00044: LearningRateScheduler reducing learning rate to tf.Tensor(4.758644e-06, shape=(), dtype=float32).
# Epoch 44/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0805 - sparse_categorical_accuracy: 0.9728
# Epoch 00044: val_loss improved from 0.19905 to 0.19359, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.0805 - sparse_categorical_accuracy: 0.9728 - val_loss: 0.1936 - val_sparse_categorical_accuracy: 0.9395
#
# Epoch 00045: LearningRateScheduler reducing learning rate to tf.Tensor(3.5111725e-06, shape=(), dtype=float32).
# Epoch 45/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0817 - sparse_categorical_accuracy: 0.9728
# Epoch 00045: val_loss improved from 0.19359 to 0.19149, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 81ms/step - loss: 0.0817 - sparse_categorical_accuracy: 0.9728 - val_loss: 0.1915 - val_sparse_categorical_accuracy: 0.9422
#
# Epoch 00046: LearningRateScheduler reducing learning rate to tf.Tensor(2.447176e-06, shape=(), dtype=float32).
# Epoch 46/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0790 - sparse_categorical_accuracy: 0.9735
# Epoch 00046: val_loss did not improve from 0.19149
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0790 - sparse_categorical_accuracy: 0.9735 - val_loss: 0.1945 - val_sparse_categorical_accuracy: 0.9406
#
# Epoch 00047: LearningRateScheduler reducing learning rate to tf.Tensor(1.5708387e-06, shape=(), dtype=float32).
# Epoch 47/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0774 - sparse_categorical_accuracy: 0.9740
# Epoch 00047: val_loss improved from 0.19149 to 0.19083, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 64s 81ms/step - loss: 0.0774 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1908 - val_sparse_categorical_accuracy: 0.9427
#
# Epoch 00048: LearningRateScheduler reducing learning rate to tf.Tensor(8.856386e-07, shape=(), dtype=float32).
# Epoch 48/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0749 - sparse_categorical_accuracy: 0.9747
# Epoch 00048: val_loss improved from 0.19083 to 0.18936, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 82ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1894 - val_sparse_categorical_accuracy: 0.9431
#
# Epoch 00049: LearningRateScheduler reducing learning rate to tf.Tensor(3.9426385e-07, shape=(), dtype=float32).
# Epoch 49/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0756 - sparse_categorical_accuracy: 0.9757
# Epoch 00049: val_loss improved from 0.18936 to 0.18576, saving model to cifar10_classification/exp1
# 800/800 [==============================] - 65s 82ms/step - loss: 0.0756 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.1858 - val_sparse_categorical_accuracy: 0.9446
#
# Epoch 00050: LearningRateScheduler reducing learning rate to tf.Tensor(9.866356e-08, shape=(), dtype=float32).
# Epoch 50/50
# 800/800 [==============================] - ETA: 0s - loss: 0.0767 - sparse_categorical_accuracy: 0.9743
# Epoch 00050: val_loss did not improve from 0.18576
# 800/800 [==============================] - 65s 81ms/step - loss: 0.0767 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1942 - val_sparse_categorical_accuracy: 0.9421

# %%
acc = history.history['sparse_categorical_accuracy']
val_acc = history.history['val_sparse_categorical_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Valid Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Valid Loss')
plt.show()

# %% [markdown]
# 모델평가

# %%
results = model.evaluate(x_test, y_test, verbose=1)
# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5859 - sparse_categorical_accuracy: 0.8500
# loss value: 0.586
# accuracy value: 85.0000%

# %%
test_batch_size = 16
batch_index = np.random.choice(len(x_test), size=test_batch_size, replace=False)

batch_xs = x_test[batch_index]
batch_ys = y_test[batch_index]
y_pred_ = model(batch_xs, training=False)

fig = plt.figure(figsize=(16, 10))
for i, (px, py) in enumerate(zip(batch_xs, y_pred_)):
  p = fig.add_subplot(4, 8, i+1)
  if np.argmax(py) == batch_ys[i]:
    p.set_title("y_pred: {}".format(np.argmax(py)), color='blue')
  else:
    p.set_title("y_pred: {}".format(np.argmax(py)), color='red')
  p.imshow(px.reshape(32, 32, 3))
  p.axis('off')

# %%
import time
t = time.time()

export_path = "/tmp/saved_models/{}".format(int(t))
model.save(export_path, save_format='tf')

export_path
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /tmp/saved_models/1604042265/assets
# '/tmp/saved_models/1604042265'
